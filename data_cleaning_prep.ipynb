# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
andic = pd.read_csv('andic_dicts.csv')
# Out:
# C:\users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,7,10,17,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
andic

# %%
akhv = pd.read_csv('akhvakhDBv5.csv')
len(akhv[akhv['bor'] == 1]['bor'].to_list())

# %%
a_borid = akhv[akhv['bor'] == 1]['id_word'].to_list()
A_borid = andic_dicts[andic['glottocode'] == 'akhv1239'][andic['bor'] == 1]['id_word'].to_list()
#compare_lists(a_borid, A_borid)['idx']
andic_dicts[andic['glottocode'] == 'akhv1239'][andic['id_word'] == 1281]['bor'].to_list()

# %%
a_idword = akhv['id_word'].to_list()
a_idmean = akhv['id_meaning'].to_list()
A_idword = andic_dicts[andic_dicts['glottocode'] == 'akhv1239']['id_word'].to_list()
A_idmean = andic_dicts[andic_dicts['glottocode'] == 'akhv1239']['id_meaning'].to_list()

# %%
def compare_lists(l1, l2):
    comp_mask = []
    comp_idx = []
    if len(l1) != len(l2):
        if len(l1) < len(l2):
            maxl = l2
            minl = l1
        else:
            maxl = l1
            minl = l2
        for j in maxl:
            if j not in minl:
                comp_idx.append(j)
        return {
            'idx': comp_idx
        }
    else:
        for i in range(len(l1)):
            if l1[i] == l2[i]:
                comp_mask.append(0)
            else:
                comp_mask.append(1)
                comp_idx.append(i)
        return {
            'mask': comp_mask,
            'idx': comp_idx
        }
    
compare_lists(a_idmean, A_idmean)['idx']

# %%
Counter(andic['glottocode'].to_list())
Counter(andic[andic['bor'] == 1]['glottocode'].to_list())

# %%
ipas = andic[['ipa', 'glottocode']]

# %%
ipas
# Out:
#                     ipa glottocode
# 0                   NaN   botl1242
# 1                   NaN   botl1242
# 2                   NaN   botl1242
# 3                   NaN   botl1242
# 4                   NaN   botl1242
# ...                 ...        ...
# 84312    ʔ-o-χʼ-'aː-ɬ-a   kara1474
# 84313         ʔ-'o-χʼ-o   kara1474
# 84314  ʔ-o-ʔ-'o-b-a-ɬ-a   kara1474
# 84315        ʔ-o-ʔ-'o-l   kara1474
# 84316        ʔ-o-ʔ-'o-l   kara1474
#
# [84317 rows x 2 columns]

# %%
ipas = ipas.dropna()

# %%
ipa_dict = {}

for _, row in ipas.iterrows():
    ipa, lang = row
    if lang not in ipa_dict:
        ipa_dict[lang] = [ipa]
    else:
        ipa_dict[lang].append(ipa)
        
c = 0
for l in ipa_dict:
    c += len(ipa_dict[l])
    
print(c)

# %%
ipa_dict

# %%
phoneme_dict = {}
for lang in sorted(list(ipa_dict.keys())):
    thLang = []
    for word in ipa_dict[lang]:
        thLang.extend(word.split('-'))
    phoneme_dict[lang] = Counter(sorted(thLang))
    
phoneme_dict

# %%
for i, row in andic.iterrows():
    if type(row['ipa']) is str and 'i:ˌ' in row['ipa']:
        print(i, row)

# %%
from_colab = {'akhv1239': Counter({'a': 13884,
          "a'": 3615,
          'aː': 547,
          "aː'": 173,
          'ã': 427,
          "ã'": 285,
          'ãː': 23,
          "ãː'": 29,
          'b': 4412,
          'd': 2828,
          'ãˌ': 81,
          'ãː': 86,
          "ãː'": 106,
          'ãːˌ': 10,
          'çʲ': 84,
          'çː': 125,
          'çːʷ': 22,
          'õ': 6,
          "õ'": 1,
          'õː': 4,
          "õː'": 16,
          'ħ': 418,
          'ħʷ': 2,
          'ĩ': 368,
          "ĩ'": 142,
          'ĩˌ': 24,
          'ĩː': 23,
          "ĩː'": 2,
          'ĩːˌ': 27,
          'ũ': 59,
          "ũ'": 189,
          'ũˌ': 9,
          'ũː': 49,
          "ũː'": 1,
          'ũːˌ': 7,
          'ɡ': 260,
          'ɡʲ': 175,
          'ɡʷ': 97,
          'ɬ': 1447,
          'ɬʲ': 2893,
          'ɬː': 272,
          'ɬːʷ': 4,
          'ʁ': 552,
          'ʁʷ': 88,
          'ʃ': 282,
          'ʃʷ': 20,
          'ʃː': 483,
          'ʃːʷ': 58,
          'ʒ': 290,
          'ʒʷ': 24,
          'ʔ': 123,
          'ʔʷ': 32,
          'ʕ': 407,
          'χ': 826,
          'χʷ': 98,
          'χː': 720,
          'χːʷ': 110,
          'ẽ': 13,
          "ẽ'": 30,
          'ẽː': 2,
          "ẽː'": 6}),
 'toki1238': Counter({"'a": 23,
          "'e": 10,
          "'i": 11,
          "'ĩ": 1,
          "'o": 2,
          "'u": 11,
          "'ũ": 1,
          'a': 180,
          'ã': 7,
          'b': 100,
          'd': 96,
          'e': 108,
          'ẽ': 2,
          'h': 27,
          'hʷ': 1,
          'i': 126,
          'ĩ': 4,
          'j': 4,
          'k': 9,
          'kʷ': 2,
          'kʼ': 15,
          'kʼʷ': 2,
          'l': 85,
          'lʼ': 5,
          'm': 6,
          'n': 36,
          'o': 31,
          'p': 2,
          'qʼ': 11,
          'qʼʷ': 2,
          'qχ': 11,
          'qχʷ': 1,
          'r': 74,
          's': 10,
          'sː': 10,
          't': 21,
          'ts': 4,
          'tsʼ': 4,
          'tsʼː': 4,
          'tsː': 3,
          'tɕ': 15,
          'tɕʷ': 2,
          'tɕʼ': 19,
          'tɕʼː': 2,
          'tɕː': 1,
          'tɬ': 4,
          'tʼ': 11,
          'tʼʷ': 1,
          'u': 134,
          'ũ': 6,
          'w': 8,
          'x': 7,
          'xʷ': 2,
          'z': 3,
          'ɡ': 16,
          'ɡʷ': 1,
          'ɬ': 18,
          'ɬː': 1,
          'ʁ': 5,
          'ʃ': 3,
          'ʃː': 13,
          'ʒ': 3,
          'ʔ': 2,
          'ʕ': 22,
          'χ': 11,
          'χʼ': 10,
          'χː': 6})}

# %%
for l in from_colab:
    print(l, len(from_colab[l]))

for l in phoneme_dict:
    print(l, len(phoneme_dict[l]))

# %%
for l in phoneme_dict:
    print(l)
    pi_ph = list(from_colab[l].keys())
    jn_ph = list(phoneme_dict[l].keys())
    if len(pi_ph) == len(jn_ph):
        for i in range(len(jn_ph)):
            if pi_ph[i] != jn_ph[i]:
                print(pi_ph[i], jn_ph[i])
    else:
        print('only_jp')
        for j in jn_ph:
            if j not in pi_ph:
                print(j)
        print('only_jp')
        for h in pi_ph:
            if h not in jn_ph:
                print(h)

# %%
# here i try to replace all bad ipa_tokens at once
def hyphen_repl(x):
    x = re.sub('-{2,}', '-', x)
    return x

def akhv_repl(x):
    x = re.sub('g', 'ɡ', x)
    x = re.sub('͡', '', x)
    return hyphen_repl(x)

def bagv_repl(x):
    x = re.sub('[\(\)\.\dа-яА-Яōé]', '', x)
    x = re.sub('͡', '', x)
    x = re.sub("a’", "a'", x)
    return hyphen_repl(x)

def cham_repl(x):
    x = re.sub('g', 'ɡ', x)
    x = re.sub('ã', 'ã', x)
    x = re.sub('ĩ', 'ĩ', x)
    x = re.sub('õ', 'õ', x)
    x = re.sub('ũ', 'ũ', x)
    x = re.sub('ẽ', 'ẽ', x)
    x = re.sub("'", "ʼ", x)
    x = re.sub("\*", "'", x)
    x = re.sub(':', "ː", x)
    return hyphen_repl(x)

def ghod_repl(x):
    x = re.sub('[ IЮЯ,]', "", x)
    x = re.sub('\uf009', '', x)
    x = re.sub('\xad', '', x)
    x = re.sub("-'-", "-", x)
    x = re.sub("'", "ʼ", x)
    x = re.sub("\*", "'", x)
    x = x.replace(":", "")
    return hyphen_repl(x)

def kara_repl(x):
    x = re.sub("\-'\-", "-", x)
    x = re.sub(r"\-'([^\-]+)\-", r"-\g<1>'-", x)
    return hyphen_repl(x)

def tind_repl(x):
    x = re.sub('ã', 'ã', x)
    x = re.sub('ĩ', 'ĩ', x)
    x = re.sub('õ', 'õ', x)
    x = re.sub('ũ', 'ũ', x)
    x = re.sub('ẽ', 'ẽ', x)
    x = re.sub('ç', 'x', x)
    x = re.sub('<', '', x)
    return hyphen_repl(x)

def toki_repl(x):
    x = re.sub('ɕ', 'ʃ', x)
    x = re.sub(r"\-'([^\-]+)\-", r"-\g<1>'-", x)
    return hyphen_repl(x)

# %%
func_dict = {
    'akhv1239': akhv_repl,
    'bagv1239': bagv_repl,
    'cham1309': cham_repl,
    'ghod1238': ghod_repl,
    'kara1474': kara_repl,
    'tind1238': tind_repl,
    'toki1238': toki_repl
}

# %%
def ipa_repl(x, func_dict=func_dict):
    if x['glottocode'] in func_dict:
        return func_dict[x['glottocode']](x['ipa'])
    else:
        return x['ipa']

# %%
ipasA = ipas.apply(ipa_repl, axis=1)

# %%
ipas

# %%
ipasA

# %%
ipas['ipa'] = ipasA

# %%
ipa_dict = {}

for _, row in ipas.iterrows():
    ipa, lang = row
    if lang not in ipa_dict:
        ipa_dict[lang] = [ipa]
    else:
        ipa_dict[lang].append(ipa)
        
phoneme_dict = {}
for lang in sorted(list(ipa_dict.keys())):
    thLang = []
    for word in ipa_dict[lang]:
        thLang.extend(word.split('-'))
    phoneme_dict[lang] = Counter(sorted(thLang))
    
phoneme_dict
# Out:
# {'akhv1239': Counter({'a': 13936,
#           "a'": 3629,
#           'aː': 549,
#           "aː'": 173,
#           'ã': 428,
#           "ã'": 287,
#           'ãː': 23,
#           "ãː'": 29,
#           'b': 4420,
#           'd': 2835,
#           'dʒ': 72,
#           'dʷ': 25,
#           'e': 7063,
#           "e'": 1803,
#           'eː': 417,
#           "eː'": 302,
#           'ẽ': 86,
#           "ẽ'": 78,
#           'ẽː': 8,
#           "ẽː'": 11,
#           'h': 1123,
#           'hʷ': 122,
#           'i': 5915,
#           "i'": 1987,
#           'iː': 24,
#           "iː'": 22,
#           'ĩ': 260,
#           "ĩ'": 185,
#           'ĩː': 5,
#           "ĩː'": 6,
#           'j': 1504,
#           'k': 946,
#           'kʷ': 155,
#           'kʼʷː': 69,
#           'kʼː': 171,
#           'kː': 21,
#           'k’': 802,
#           'k’ʷ': 201,
#           'l': 2876,
#           'lʷ': 1,
#           'lː': 28,
#           'm': 1701,
# ...

# %%
## it's from main notebook, might delete later
phoneme_dict = {}
ipa_dict = {}
for lang in pivot_ipa.columns:
    all_list = pivot_ipa[lang].to_list()
    ph_list = []
    ipa_dict[lang] = all_list
    for row in all_list:
        if type(row) == list:
            for word in row:
                try:
                    ph_list.extend(word.split('-'))
                except:
                    print(lang, row, word)
    #phoneme_dict[lang] = sorted(list(set(ph_list)))
    phoneme_dict[lang] = Counter(ph_list)
phoneme_dict

# %%
# !pip install lingpy
# Out:
# ...
#   Created wheel for lingpy: filename=lingpy-2.6.7-py3-none-any.whl size=589567 sha256=be5cbe6faa85808e018f1a3ada66d2ac7b427da2ab31caeb387033b64aa05f8d
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\e4\d0\c7\97f18ecde9e623ca755417665ac069033a9179c51a31179cfd
# Successfully built lingpy
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\admin\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import lingpy.align.pairwise as lp_pw

# %%
import lingpy as lp

# %%
dolgo = lp.data.model.Model('dolgo')

# %%
for lang in phoneme_dict:
    print(lang)
    chars = list(phoneme_dict[lang].keys())
    for c in chars:
        try:
            print("{0}: {1}".format(c, dolgo.converter[c]))
        except KeyError:
            print("{0}: ERROR".format(c))
# Out:
# akhv1239
# a: V
# a': ERROR
# aː: ERROR
# aː': ERROR
# ã: ERROR
# ã': ERROR
# ãː: ERROR
# ãː': ERROR
# b: P
# d: T
# dʒ: ERROR
# dʷ: ERROR
# e: V
# e': ERROR
# eː: ERROR
# eː': ERROR
# ẽ: ERROR
# ẽ': ERROR
# ẽː: ERROR
# ẽː': ERROR
# h: H
# hʷ: ERROR
# i: V
# i': ERROR
# iː: ERROR
# iː': ERROR
# ĩ: ERROR
# ĩ': ERROR
# ĩː: ERROR
# ĩː': ERROR
# j: J
# k: K
# kʷ: ERROR
# kʼʷː: ERROR
# kʼː: ERROR
# kː: ERROR
# k’: ERROR
# k’ʷ: ERROR
# l: R
# lʷ: ERROR
# lː: ERROR
# m: M
# mː: ERROR
# n: N
# o: V
# o': ERROR
# oː: ERROR
# oː': ERROR
# õ': ERROR
# õː: ERROR
# õː': ERROR
# p: P
# p’: ERROR
# qχ: ERROR
# qχʷ: ERROR
# qχʷː: ERROR
# qχː: ERROR
# qχ’: ERROR
# qχ’ʷ: ERROR
# qχ’ʷː: ERROR
# qχ’ː: ERROR
# r: R
# s: S
# sʷ: ERROR
# sʷː: ERROR
# sː: ERROR
# t: T
# ts: K
# tsʷː: ERROR
# tsː: ERROR
# ts’: ERROR
# ts’ʷː: ERROR
# ts’ː: ERROR
# tɬ: ERROR
# tɬʷ: ERROR
# tɬʼ: ERROR
# tɬʼʷ: ERROR
# tɬʼʷː: ERROR
# tɬʼː: ERROR
# tɬː: ERROR
# tʃ: ERROR
# tʃʷ: ERROR
# tʃː: ERROR
# tʃ’: ERROR
# ...

# %%
ipa_dict = {}


for _, row in ipas.iterrows():
    ipa, lang = row
    if lang not in ipa_dict:
        ipa_dict[lang] = [ipa]
    else:
        ipa_dict[lang].append(ipa)

def to_turch(x):
    x = re.sub("['ː̃ʷʼ’ʲˌ̄,]", '', x)
    x = re.sub("qχ", 'q', x)
    x = re.sub("о", "o", x)
    x = re.sub("ћ", "ħ", x)
    x = re.sub(r"d([zʒ])", r"d͡\g<1>", x)
    x = re.sub(r"t([ʃsɬɕ])", r"t͡\g<1>", x)
    return x

phoneme_dict = {}
for lang in sorted(list(ipa_dict.keys())):
    thLang = []
    for word in ipa_dict[lang]:
        word = to_turch(word)
        thLang.extend(word.split('-'))
    phoneme_dict[lang] = Counter(sorted(thLang))
    
phoneme_dict
# Out:
# {'akhv1239': Counter({'a': 19054,
#           'b': 4420,
#           'd': 2860,
#           'd͡ʒ': 72,
#           'e': 9768,
#           'h': 1245,
#           'i': 8404,
#           'j': 1504,
#           'k': 2365,
#           'l': 2905,
#           'm': 1702,
#           'n': 1542,
#           'o': 4360,
#           'p': 271,
#           'q': 3263,
#           'r': 5883,
#           's': 1398,
#           't': 2425,
#           't͡s': 855,
#           't͡ɬ': 5397,
#           't͡ʃ': 2287,
#           'u': 8439,
#           'w': 177,
#           'x': 404,
#           'z': 387,
#           'ħ': 962,
#           'ɡ': 934,
#           'ɬ': 1711,
#           'ʁ': 598,
#           'ʃ': 1330,
#           'ʒ': 437,
#           'ʔ': 125,
#           'ʕ': 615,
#           'χ': 1421}),
#  'bagv1239': Counter({'': 15,
#           'a': 21443,
#           'b': 5287,
#           'd': 3225,
#           'd͡ʒ': 401,
#           'e': 3206,
#           'h': 3213,
#           'i': 7416,
# ...

# %%
for lang in phoneme_dict:
    print(lang)
    chars = list(phoneme_dict[lang].keys())
    for c in chars:
        try:
            print("{0}: {1}".format(c, dolgo.converter[c]))
        except KeyError:
            print("{0}: ERROR".format(c))
# Out:
# akhv1239
# a: V
# b: P
# d: T
# d͡ʒ: K
# e: V
# h: H
# i: V
# j: J
# k: K
# l: R
# m: M
# n: N
# o: V
# p: P
# q: K
# r: R
# s: S
# t: T
# t͡s: K
# t͡ɬ: ERROR
# t͡ʃ: K
# u: V
# w: W
# x: K
# z: S
# ħ: H
# ɡ: K
# ɬ: R
# ʁ: R
# ʃ: S
# ʒ: S
# ʔ: H
# ʕ: H
# χ: K
# bagv1239
# : ERROR
# a: V
# b: P
# d: T
# d͡ʒ: K
# e: V
# h: H
# i: V
# j: J
# k: K
# l: R
# m: M
# n: N
# o: V
# p: P
# q: K
# r: R
# s: S
# t: T
# t͡s: K
# t͡ɬ: ERROR
# t͡ʃ: K
# u: V
# w: W
# w,: ERROR
# x: K
# z: S
# ɡ: K
# ɬ: R
# ʁ: R
# ʃ: S
# ʒ: S
# ʔ: H
# ʕ: H
# χ: K
# cham1309
# a: V
# b: P
# d: T
# d͡z: K
# e: V
# h: H
# i: V
# j: J
# k: K
# l: R
# m: M
# n: N
# o: V
# p: P
# q: K
# r: R
# s: S
# t: T
# t͡s: K
# t͡ɬ: ERROR
# t͡ʃ: K
# u: V
# w: W
# x: K
# z: S
# ã: V
# ħ: H
# ĩ: V
# ũ: V
# ɡ: K
# ɬ: R
# ʁ: R
# ʃ: S
# ʒ: S
# ʔ: H
# ʕ: H
# χ: K
# ghod1238
# : ERROR
# a: V
# b: P
# d: T
# d͡ʒ: K
# e: V
# h: H
# i: V
# j: J
# k: K
# l: R
# m: M
# n: N
# o: V
# p: P
# q: K
# r: R
# s: S
# t: T
# t͡s: K
# t͡ɬ: ERROR
# t͡ʃ: K
# ...

# %%
dift = []
for lang in phoneme_dict:
    for c in list(phoneme_dict[lang].keys()):
        if len(c) > 1:
            dift.append(c)
            
print(list(set(dift)))
# Out:
# ['dʒ', 'tɬ', 'tɕ', 'tʃ', 'dz', 'l̄', 'ts', 'w,']

# %%
print(dolgo.converter)
# Out:
# {'a': 'V', 'ᴀ': 'V', 'ã': 'V', 'ɑ': 'V', 'á': 'V', 'à': 'V', 'ā': 'V', 'ǎ': 'V', 'ụ': 'V', 'ū': 'V', 'â': 'V', 'ɛ': 'V', 'æ': 'V', 'ɜ': 'V', 'ɐ': 'V', 'ʌ': 'V', 'e': 'V', 'ᴇ': 'V', 'ə': 'V', 'ẽ': 'V', 'ɘ': 'V', 'ɤ': 'V', 'è': 'V', 'é': 'V', 'ē': 'V', 'ě': 'V', 'ê': 'V', 'ɚ': 'V', 'Œ': 'V', 'ɒ': 'V', 'œ': 'V', 'ɞ': 'V', 'ɔ': 'V', 'ø': 'V', 'ɵ': 'V', 'o': 'V', 'õ': 'V', 'ó': 'V', 'ò': 'V', 'ō': 'V', 'ô': 'V', 'y': 'V', 'ṳ': 'V', 'ʏ': 'V', 'ʉ': 'V', 'u': 'V', 'ᴜ': 'V', 'ʊ': 'V', 'i': 'V', 'ɪ': 'V', 'ɨ': 'V', 'ɿ': 'V', 'ʅ': 'V', 'ɯ': 'V', 'ĩ': 'V', 'í': 'V', 'ǐ': 'V', 'ì': 'V', 'î': 'V', 'ī': 'V', 'ɶ': 'V', 'ɷ': 'V', 'ı': 'V', 'ǝ': 'V', 'ǒ': 'V', 'ĭ': 'V', 'ŏ': 'V', 'ä': 'V', 'ö': 'V', 'ŭ': 'V', 'ў': 'V', 'ă': 'V', 'ĕ': 'V', 'ü': 'V', 'ú': 'V', 'ũ': 'V', 'ṵ': 'V', 'ʮ': 'V', 'ɩ': 'V', 'ỹ': 'V', 'ε': 'V', 'ù': 'V', 'е': 'V', 'ï': 'V', 'ǔ': 'V', 'ạ': 'V', 'ọ': 'V', 'ỳ': 'V', 'ȯ': 'V', 'û': 'V', 'а': 'V', 'ę': 'V', 'ị': 'V', 'ý': 'V', 'å': 'V', 'ǫ': 'V', 'ë': 'V', 'ḭ': 'V', 'ḛ': 'V', 'ๅ': 'V
# ...

# %%
dolgo.info
# Out:
# {'description': 'Sound-Class model based on Dolgopolsky (1986)',
#  'compiler': 'Johann-Mattis List',
#  'source': 'Dolgopolsky (1986)',
#  'date': '2012-03',
#  'vowels': 'V',
#  'tones': 'unknown'}

# %%
rev_dolgo = {}
for char in dolgo.converter:
    cl = dolgo.converter[char]
    if cl in rev_dolgo:
        rev_dolgo[cl].append(char)
    else:
        rev_dolgo[cl] = [char]
        
rev_dolgo
# Out:
# {'V': ['a',
#   'ᴀ',
#   'ã',
#   'ɑ',
#   'á',
#   'à',
#   'ā',
#   'ǎ',
#   'ụ',
#   'ū',
#   'â',
#   'ɛ',
#   'æ',
#   'ɜ',
#   'ɐ',
#   'ʌ',
#   'e',
#   'ᴇ',
#   'ə',
#   'ẽ',
#   'ɘ',
#   'ɤ',
#   'è',
#   'é',
#   'ē',
#   'ě',
#   'ê',
#   'ɚ',
#   'Œ',
#   'ɒ',
#   'œ',
#   'ɞ',
#   'ɔ',
#   'ø',
#   'ɵ',
#   'o',
#   'õ',
#   'ó',
#   'ò',
#   'ō',
#   'ô',
#   'y',
#   'ṳ',
#   'ʏ',
#   'ʉ',
#   'u',
#   'ᴜ',
#   'ʊ',
#   'i',
#   'ɪ',
#   'ɨ',
#   'ɿ',
#   'ʅ',
#   'ɯ',
#   'ĩ',
#   'í',
#   'ǐ',
#   'ì',
#   'î',
#   'ī',
#   'ɶ',
#   'ɷ',
#   'ı',
#   'ǝ',
#   'ǒ',
#   'ĭ',
#   'ŏ',
#   'ä',
#   'ö',
#   'ŭ',
#   'ў',
#   'ă',
#   'ĕ',
#   'ü',
#   'ú',
#   'ũ',
#   'ṵ',
#   'ʮ',
#   'ɩ',
#   'ỹ',
#   'ε',
#   'ù',
#   'е',
#   'ï',
#   'ǔ',
#   'ạ',
#   'ọ',
#   'ỳ',
#   'ȯ',
#   'û',
#   'а',
#   'ę',
#   'ị',
#   'ý',
#   'å',
#   'ǫ',
#   'ë',
#   'ḭ',
#   'ḛ',
#   'ๅ',
#   'ố',
#   'ȇ',
#   'ȗ',
#   'ṍ',
#   'ṹ',
#   'ŷ',
#   'ʯ'],
#  'K': ['t͡s',
#   't͜s',
# ...

# %%
for c in dolgo.converter:
    if 'ƛ' in c or 't' in c:
        print(c)
# Out:
# t͡s
# t͜s
# t͡ɕ
# t͜ɕ
# t͡ʃ
# t͜ʃ
# t͡ʂ
# t͜ʂ
# t͡θ
# t͜θ
# tɕ
# tɕʰ
# ts
# tsʰ
# t
